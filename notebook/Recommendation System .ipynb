# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Đọc file movies.csv (sửa đường dẫn nếu chạy trên Colab)
data = pd.read_csv(
    "movie_data/movies.csv",   # đúng đường dẫn
    sep="\t",
    encoding='latin1',
    usecols=["movie_id", "title", "genres"]
)


print("Đọc dữ liệu xong")
print(data.shape)
data.head()
# Out:
# Đọc dữ liệu xong
# (3883, 3)
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
# Thay | bằng khoảng trắng và bỏ dấu -
data["genres"] = data["genres"].apply(lambda s: s.replace("|", " ").replace("-", ""))

print("Tiền xử lý dữ liệu xong")
data.head()
# Out:
# Tiền xử lý dữ liệu xong
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation Children's Comedy
# 1         2                      Jumanji (1995)  Adventure Children's Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy Romance
# 3         4            Waiting to Exhale (1995)                  Comedy Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(data["genres"])

print("Tạo TF-IDF xong")
print("TF-IDF shape:", tfidf_matrix.shape)
# Out:
# Tạo TF-IDF xong
# TF-IDF shape: (3883, 18)

# %%
cosine_sim = cosine_similarity(tfidf_matrix)
cosine_sim_df = pd.DataFrame(cosine_sim, index=data["title"], columns=data["title"])

print("Ma trận cosine similarity xong")
cosine_sim_df.head(5)
# Out:
# Ma trận cosine similarity xong
# title                               Toy Story (1995)  Jumanji (1995)  \
# title
# Toy Story (1995)                            1.000000        0.305525
# Jumanji (1995)                              0.305525        1.000000
# Grumpier Old Men (1995)                     0.197372        0.000000
# Waiting to Exhale (1995)                    0.260194        0.000000
# Father of the Bride Part II (1995)          0.344351        0.000000
#
# title                               Grumpier Old Men (1995)  \
# title
# Toy Story (1995)                                   0.197372
# Jumanji (1995)                                     0.000000
# Grumpier Old Men (1995)                            1.000000
# Waiting to Exhale (1995)                           0.433093
# Father of the Bride Part II (1995)                 0.573172
#
# title                               Waiting to Exhale (1995)  \
# title
# Toy Story (1995)                                    0.260194
# Jumanji (1995)                                      0.000000
# Grumpier Old Men (1995)                             0.433093
# Waiting to Exhale (1995)                            1.000000
# Father of the Bride Part II (1995)                  0.755606
#
# title                               Father of the Bride Part II (1995)  \
# title
# Toy Story (1995)                                              0.344351
# Jumanji (1995)                                                0.000000
# Grumpier Old Men (1995)                                       0.573172
# Waiting to Exhale (1995)                                      0.755606
# Father of the Bride Part II (1995)                            1.000000
#
# title                               Heat (1995)  Sabrina (1995)  \
# title
# Toy Story (1995)                            0.0        0.197372
# Jumanji (1995)                              0.0        0.000000
# Grumpier Old Men (1995)                     0.0        1.000000
# Waiting to Exhale (1995)                    0.0        0.433093
# Father of the Bride Part II (1995)          0.0        0.573172
#
# title                               Tom and Huck (1995)  Sudden Death (1995)  \
# title
# Toy Story (1995)                               0.425153                  0.0
# Jumanji (1995)                                 0.718623                  0.0
# Grumpier Old Men (1995)                        0.000000                  0.0
# Waiting to Exhale (1995)                       0.000000                  0.0
# Father of the Bride Part II (1995)             0.000000                  0.0
#
# title                               GoldenEye (1995)  ...  Bamboozled (2000)  \
# title                                                 ...
# Toy Story (1995)                             0.00000  ...           0.344351
# Jumanji (1995)                               0.32089  ...           0.000000
# Grumpier Old Men (1995)                      0.00000  ...           0.573172
# Waiting to Exhale (1995)                     0.00000  ...           0.755606
# Father of the Bride Part II (1995)           0.00000  ...           1.000000
#
# title                               Bootmen (2000)  Digimon: The Movie (2000)  \
# title
# Toy Story (1995)                          0.260194                   0.801460
# Jumanji (1995)                            0.000000                   0.538118
# Grumpier Old Men (1995)                   0.433093                   0.000000
# Waiting to Exhale (1995)                  1.000000                   0.000000
# Father of the Bride Part II (1995)        0.755606                   0.000000
#
# title                               Get Carter (2000)  Get Carter (1971)  \
# title
# Toy Story (1995)                             0.000000                0.0
# Jumanji (1995)                               0.000000                0.0
# Grumpier Old Men (1995)                      0.000000                0.0
# Waiting to Exhale (1995)                     0.262005                0.0
# Father of the Bride Part II (1995)           0.000000                0.0
#
# title                               Meet the Parents (2000)  \
# title
# Toy Story (1995)                                   0.344351
# Jumanji (1995)                                     0.000000
# Grumpier Old Men (1995)                            0.573172
# Waiting to Exhale (1995)                           0.755606
# Father of the Bride Part II (1995)                 1.000000
#
# title                               Requiem for a Dream (2000)  \
# title
# Toy Story (1995)                                      0.000000
# Jumanji (1995)                                        0.000000
# Grumpier Old Men (1995)                               0.000000
# Waiting to Exhale (1995)                              0.655026
# Father of the Bride Part II (1995)                    0.000000
#
# title                               Tigerland (2000)  Two Family House (2000)  \
# title
# Toy Story (1995)                            0.000000                 0.000000
# Jumanji (1995)                              0.000000                 0.000000
# Grumpier Old Men (1995)                     0.000000                 0.000000
# Waiting to Exhale (1995)                    0.655026                 0.655026
# Father of the Bride Part II (1995)          0.000000                 0.000000
#
# title                               Contender, The (2000)
# title
# Toy Story (1995)                                 0.000000
# Jumanji (1995)                                   0.000000
# Grumpier Old Men (1995)                          0.000000
# Waiting to Exhale (1995)                         0.343133
# Father of the Bride Part II (1995)               0.000000
#
# [5 rows x 3883 columns]

# %%
seen_movie = "Quick and the Dead, The (1995)"
top_k = 20

top_movies = cosine_sim_df.loc[seen_movie, :].sort_values(ascending=False)[:top_k]

print(f"Top {top_k} phim giống '{seen_movie}':")
top_movies
# Out:
# Top 20 phim giống 'Quick and the Dead, The (1995)':
# title
# Quick and the Dead, The (1995)               1.000000
# Tashunga (1995)                              0.897620
# True Grit (1969)                             0.897620
# Dances with Wolves (1990)                    0.858772
# Good, The Bad and The Ugly, The (1966)       0.851792
# Fistful of Dollars, A (1964)                 0.851792
# Last Man Standing (1996)                     0.811141
# Young Guns II (1990)                         0.798927
# Young Guns (1988)                            0.798927
# Maverick (1994)                              0.798927
# Butch Cassidy and the Sundance Kid (1969)    0.798927
# Duel in the Sun (1946)                       0.728884
# MacKenna's Gold (1969)                       0.728884
# Unforgiven (1992)                            0.728884
# Wild Bunch, The (1969)                       0.728884
# Dead Man (1995)                              0.728884
# Once Upon a Time in the West (1969)          0.728884
# Cimarron (1931)                              0.728884
# Wyatt Earp (1994)                            0.728884
# Outlaw, The (1943)                           0.728884
# Name: Quick and the Dead, The (1995), dtype: float64

# %%
top_movies_df = top_movies.reset_index()
top_movies_df.columns = ["Movie", "Similarity Score"]
top_movies_df
# Out:
#                                         Movie  Similarity Score
# 0              Quick and the Dead, The (1995)          1.000000
# 1                             Tashunga (1995)          0.897620
# 2                            True Grit (1969)          0.897620
# 3                   Dances with Wolves (1990)          0.858772
# 4      Good, The Bad and The Ugly, The (1966)          0.851792
# 5                Fistful of Dollars, A (1964)          0.851792
# 6                    Last Man Standing (1996)          0.811141
# 7                        Young Guns II (1990)          0.798927
# 8                           Young Guns (1988)          0.798927
# 9                             Maverick (1994)          0.798927
# 10  Butch Cassidy and the Sundance Kid (1969)          0.798927
# 11                     Duel in the Sun (1946)          0.728884
# 12                     MacKenna's Gold (1969)          0.728884
# 13                          Unforgiven (1992)          0.728884
# 14                     Wild Bunch, The (1969)          0.728884
# 15                            Dead Man (1995)          0.728884
# 16        Once Upon a Time in the West (1969)          0.728884
# 17                            Cimarron (1931)          0.728884
# 18                          Wyatt Earp (1994)          0.728884
# 19                         Outlaw, The (1943)          0.728884
